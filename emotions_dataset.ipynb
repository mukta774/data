# %% [markdown]
# <a href="https://colab.research.google.com/github/mukta774/data/blob/main/emotions_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the train.txt file
train_df = pd.read_csv("/content/sample_data/train.txt", sep=";", header=None, names=["text", "emotion"])
test_df = pd.read_csv("/content/sample_data/test.txt", sep=";", header=None, names=["text", "emotion"])
# Clean up whitespace if need
df["text"] = df["text"].str.strip()
df["emotion"] = df["emotion"].str.strip()

print(train_df.head())
# Out:
#                                                 text  emotion
# 0                            i didnt feel humiliated  sadness
# 1  i can go from feeling so hopeless to so damned...  sadness
# 2   im grabbing a minute to post i feel greedy wrong    anger
# 3  i am ever feeling nostalgic about the fireplac...     love
# 4                               i am feeling grouchy    anger

# %%
df.describe()
# Out:
#                                     text emotion
# count                              15999   15999
# unique                             15969       6
# top     i still feel completely accepted     joy
# freq                                   2    5361

# %%
print("No. of duplicates : ",df.duplicated().sum())
print("After dropping the duplicates : ",df.drop_duplicates(inplace=True))
# Out:
# No. of duplicates :  0
# After dropping the duplicates :  None

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# Split the raw text and labels first
#X_train_text, X_test_text, y_train, y_test = train_test_split(df["text"], df["emotion"], test_size=0.2, random_state=42)

X_train_text, X_test_text, y_train, y_test = train_test_split(
    df["text"], df["emotion"], test_size=0.2, stratify=df["emotion"], random_state=42
)

# Vectorize after splitting
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

# Train model on vectorized data
model = MultinomialNB()
model.fit(X_train, y_train)

# Predict & evaluate
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.91      0.17      0.29       439
#         fear       0.91      0.10      0.19       375
#          joy       0.54      0.99      0.70      1027
#         love       1.00      0.01      0.02       303
#      sadness       0.71      0.89      0.79       950
#     surprise       0.00      0.00      0.00       106
#
#     accuracy                           0.62      3200
#    macro avg       0.68      0.36      0.33      3200
# weighted avg       0.71      0.62      0.52      3200
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# %%
print(y_test.value_counts())
# Out:
# emotion
# joy         1027
# sadness      950
# anger        439
# fear         375
# love         303
# surprise     106
# Name: count, dtype: int64
